# %%
from pathlib import Path
import json
import yaml
import torch
import matplotlib.pyplot as plt

from project_main.tokens import build_vocab
from project_main.data import make_batch, make_eval_batch

# %%
CONFIG_PATH = Path("../configs/base.yaml")
with open(CONFIG_PATH, "r") as f:
    cfg = yaml.safe_load(f)

# %%
vocab = build_vocab(cfg['task'])
print(vocab.size)
print(vocab.newline_id)
print(vocab.decode(list(range(vocab.size))))
# Out:
# Building vocab...
# ('BOS', '_NEWLINE_')
# 82
# 1
# ['BOS', '_NEWLINE_', 'TOKEN_0_1', 'TOKEN_1_1', 'TOKEN_2_1', 'TOKEN_3_1', 'TOKEN_4_1', 'TOKEN_5_1', 'TOKEN_6_1', 'TOKEN_7_1', 'TOKEN_8_1', 'TOKEN_9_1', 'TOKEN_0_2', 'TOKEN_1_2', 'TOKEN_2_2', 'TOKEN_3_2', 'TOKEN_4_2', 'TOKEN_5_2', 'TOKEN_6_2', 'TOKEN_7_2', 'TOKEN_8_2', 'TOKEN_9_2', 'TOKEN_0_3', 'TOKEN_1_3', 'TOKEN_2_3', 'TOKEN_3_3', 'TOKEN_4_3', 'TOKEN_5_3', 'TOKEN_6_3', 'TOKEN_7_3', 'TOKEN_8_3', 'TOKEN_9_3', 'TOKEN_0_4', 'TOKEN_1_4', 'TOKEN_2_4', 'TOKEN_3_4', 'TOKEN_4_4', 'TOKEN_5_4', 'TOKEN_6_4', 'TOKEN_7_4', 'TOKEN_8_4', 'TOKEN_9_4', 'TOKEN_0_5', 'TOKEN_1_5', 'TOKEN_2_5', 'TOKEN_3_5', 'TOKEN_4_5', 'TOKEN_5_5', 'TOKEN_6_5', 'TOKEN_7_5', 'TOKEN_8_5', 'TOKEN_9_5', 'TOKEN_0_6', 'TOKEN_1_6', 'TOKEN_2_6', 'TOKEN_3_6', 'TOKEN_4_6', 'TOKEN_5_6', 'TOKEN_6_6', 'TOKEN_7_6', 'TOKEN_8_6', 'TOKEN_9_6', 'TOKEN_0_7', 'TOKEN_1_7', 'TOKEN_2_7', 'TOKEN_3_7', 'TOKEN_4_7', 'TOKEN_5_7', 'TOKEN_6_7', 'TOKEN_7_7', 'TOKEN_8_7', 'TOKEN_9_7', 'TOKEN_0_8', 'TOKEN_1_8', 'TOKEN_2_8', 'TOKEN_3_8', 'TOKEN_4_8', 'TOKEN_5_8', 'TOKEN_6_8', 'TOKEN_7_8', 'TOKEN_8_8', 'TOKEN_9_8']

# %%
batch = make_batch(task_cfg=cfg['task'], vocab=vocab, batch_size=1,device="cpu")
for i in range(1):
    print(f"Example {i}:")
    print("Input: ", vocab.decode(batch.tokens[i].tolist()))
    print("Target: ", vocab.decode(batch.targets[i].tolist()))
    print()
# Out:
# Example 0:
# Input:  ['BOS', 'TOKEN_3_2', 'TOKEN_0_7', 'TOKEN_8_5', 'TOKEN_7_4', 'TOKEN_5_3', 'TOKEN_2_8', 'TOKEN_4_2', 'TOKEN_0_6', 'TOKEN_0_6', 'TOKEN_3_7', 'TOKEN_1_5', 'TOKEN_7_5', 'TOKEN_9_8', '_NEWLINE_', 'TOKEN_3_5', 'TOKEN_1_1', 'TOKEN_6_2', 'TOKEN_1_2', 'TOKEN_8_2', 'TOKEN_9_4', 'TOKEN_6_6', 'TOKEN_0_4', 'TOKEN_2_3', 'TOKEN_8_3', 'TOKEN_6_7', 'TOKEN_9_6', 'TOKEN_3_3', 'TOKEN_9_3', 'TOKEN_3_5', 'TOKEN_2_5', 'TOKEN_6_6', 'TOKEN_3_2', '_NEWLINE_', 'TOKEN_9_6', 'TOKEN_2_3', 'TOKEN_0_3', 'TOKEN_4_1', 'TOKEN_2_2', 'TOKEN_2_8', 'TOKEN_9_5', 'TOKEN_4_4', 'TOKEN_5_