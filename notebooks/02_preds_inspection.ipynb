# %%
from pathlib import Path
import json
import yaml
import torch
import matplotlib.pyplot as plt

from project_main.tokens import build_vocab
from project_main.data import make_batch, make_eval_batch
from project_main.model import build_model
from project_main.checkpoints import load_checkpoint

# %%
RUN_DIR = Path("../results/line_breaks_results")
CHECKPOINT_PATH = RUN_DIR / "checkpoints" / "final.pt"
with open(RUN_DIR / "config.json", "r") as f:
    cfg = json.load(f)

device = "cpu"
vocab = build_vocab(cfg['task'])
model = build_model(cfg=cfg, device=device)

checkpoint = load_checkpoint(path=CHECKPOINT_PATH, model=model,map_location=device)
model.eval()

checkpoint['step']
# Out:
# 10000

# %%
for i in range(10):
    batch = make_batch(task_cfg=cfg['task'], vocab=vocab, batch_size=1, device=device)
    with torch.no_grad():
        logits = model(batch.tokens)
        predictions = torch.argmax(logits, dim=-1)
print(f"Example: {i}")
# print("Input: ", vocab.decode(batch.tokens[0].tolist()))
print("Targs: ", vocab.decode(batch.targets[0].tolist()))
print("Preds: ", vocab.decode(predictions[0].tolist()))
# Out:
# Example: 0
# Targs:  ['TOKEN_0_4', 'TOKEN_0_4', 'TOKEN_0_4', 'TOKEN_0_1', 'TOKEN_1_5', 'TOKEN_1_6', 'TOKEN_0_6', 'NEWLINE', 'TOKEN_0_8', 'TOKEN_0_5', 'TOKEN_1_1', 'TOKEN_1_5', 'TOKEN_0_7', 'TOKEN_1_1', 'NEWLINE', 'TOKEN_1_5', 'TOKEN_1_3', 'TOKEN_0_6', 'TOKEN_0_8', 'TOKEN_1_7']
# Preds:  ['TOKEN_0_4', 'TOKEN_0_4', 'TOKEN_0_4', 'TOKEN_1_8', 'TOKEN_1_1', 'TOKEN_1_1', 'NEWLINE', 'NEWLINE', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1', 'NEWLINE', 'NEWLINE', 'TOKEN_0_8', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1']
# Example: 1
# Targs:  ['TOKEN_0_6', 'TOKEN_0_5', 'TOKEN_0_8', 'TOKEN_1_5', 'TOKEN_0_5', 'NEWLINE', 'TOKEN_1_7', 'TOKEN_1_5', 'TOKEN_1_8', 'TOKEN_1_7', 'NEWLINE', 'TOKEN_1_7', 'TOKEN_1_2', 'TOKEN_0_4', 'TOKEN_0_2', 'TOKEN_1_2', 'TOKEN_0_6', 'TOKEN_1_4', 'NEWLINE', 'TOKEN_0_7']
# Preds:  ['TOKEN_0_4', 'TOKEN_1_8', 'TOKEN_1_8', 'TOKEN_1_1', 'NEWLINE', 'NEWLINE', 'TOKEN_1_8', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1', 'NEWLINE', 'TOKEN_0_8', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1', 'NEWLINE', 'NEWLINE', 'TOKEN_0_8']
# Example: 2
# Targs:  ['TOKEN_0_7', 'TOKEN_1_6', 'TOKEN_1_6', 'TOKEN_0_5', 'NEWLINE', 'TOKEN_0_7', 'TOKEN_1_3', 'TOKEN_0_5', 'TOKEN_1_3', 'TOKEN_0_4', 'TOKEN_1_8', 'NEWLINE', 'TOKEN_1_1', 'TOKEN_1_7', 'TOKEN_0_5', 'TOKEN_0_5', 'TOKEN_1_8', 'TOKEN_1_2', 'NEWLINE', 'TOKEN_0_8']
# Preds:  ['TOKEN_0_4', 'TOKEN_1_8', 'TOKEN_1_8', 'TOKEN_1_1', 'NEWLINE', 'TOKEN_1_7', 'TOKEN_0_4', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1', 'NEWLINE', 'TOKEN_1_8', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1', 'NEWLINE', 'NEWLINE', 'TOKEN_0_8']
# Example: 3
# Targs:  ['TOKEN_1_5', 'TOKEN_0_6', 'TOKEN_1_7', 'TOKEN_0_1', 'TOKEN_0_4', 'TOKEN_0_5', 'TOKEN_1_1', 'NEWLINE', 'TOKEN_1_8', 'TOKEN_0_2', 'TOKEN_0_6', 'TOKEN_1_5', 'TOKEN_0_6', 'NEWLINE', 'TOKEN_0_4', 'TOKEN_0_8', 'TOKEN_1_8', 'TOKEN_1_8', 'NEWLINE', 'TOKEN_0_8']
# Preds:  ['TOKEN_0_4', 'TOKEN_1_8', 'TOKEN_1_8', 'TOKEN_1_8', 'TOKEN_1_1', 'NEWLINE', 'NEWLINE', 'NEWLINE', 'TOKEN_1_8', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1', 'NEWLINE', 'TOKEN_0_8', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_0_4', 'NEWLINE', 'TOKEN_1_6']
# Example: 4
# Targs:  ['TOKEN_1_2', 'TOKEN_1_4', 'TOKEN_0_7', 'TOKEN_1_2', 'TOKEN_1_5', 'TOKEN_1_3', 'TOKEN_0_6', 'TOKEN_1_1', 'NEWLINE', 'TOKEN_1_3', 'TOKEN_0_1', 'TOKEN_0_3', 'TOKEN_1_8', 'TOKEN_0_1', 'TOKEN_1_3', 'TOKEN_1_8', 'TOKEN_1_3', 'NEWLINE', 'TOKEN_0_7', 'TOKEN_1_4']
# Preds:  ['TOKEN_0_4', 'TOKEN_0_4', 'TOKEN_0_4', 'TOKEN_1_8', 'TOKEN_1_1', 'TOKEN_1_1', 'NEWLINE', 'NEWLINE', 'NEWLINE', 'TOKEN_1_8', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_0_4', 'NEWLINE', 'NEWLINE', 'TOKEN_1_1', 'TOKEN_1_1']
# Example: 5
# Targs:  ['TOKEN_1_2', 'TOKEN_0_4', 'TOKEN_1_1', 'TOKEN_1_7', 'TOKEN_1_2', 'TOKEN_0_4', 'TOKEN_1_5', 'TOKEN_1_1', 'NEWLINE', 'TOKEN_1_6', 'TOKEN_0_6', 'TOKEN_0_7', 'TOKEN_0_1', 'TOKEN_0_2', 'TOKEN_0_4', 'TOKEN_0_1', 'NEWLINE', 'TOKEN_1_6', 'TOKEN_1_5', 'TOKEN_1_5']
# Preds:  ['TOKEN_0_4', 'TOKEN_0_4', 'TOKEN_0_4', 'TOKEN_1_8', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1', 'NEWLINE', 'NEWLINE', 'TOKEN_0_7', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1', 'NEWLINE', 'NEWLINE', 'TOKEN_0_8', 'TOKEN_1_1', 'TOKEN_1_1']
# Example: 6
# Targs:  ['TOKEN_1_2', 'TOKEN_0_2', 'TOKEN_1_1', 'TOKEN_1_5', 'TOKEN_0_2', 'TOKEN_1_7', 'TOKEN_1_4', 'NEWLINE', 'TOKEN_0_8', 'TOKEN_0_7', 'TOKEN_0_8', 'TOKEN_0_5', 'NEWLINE', 'TOKEN_1_7', 'TOKEN_1_6', 'TOKEN_1_1', 'TOKEN_1_3', 'TOKEN_1_1', 'TOKEN_0_7', 'TOKEN_0_4']
# Preds:  ['TOKEN_0_4', 'TOKEN_0_4', 'TOKEN_0_4', 'TOKEN_0_4', 'TOKEN_1_1', 'TOKEN_0_4', 'TOKEN_1_1', 'NEWLINE', 'TOKEN_0_8', 'TOKEN_1_1', 'TOKEN_1_1', 'NEWLINE', 'NEWLINE', 'TOKEN_1_3', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1', 'NEWLINE']
# Example: 7
# Targs:  ['TOKEN_0_1', 'TOKEN_0_3', 'TOKEN_1_5', 'TOKEN_0_6', 'TOKEN_0_5', 'TOKEN_0_4', 'TOKEN_1_1', 'NEWLINE', 'TOKEN_0_6', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_3', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_3', 'TOKEN_1_8', 'TOKEN_1_3', 'NEWLINE', 'TOKEN_1_5', 'TOKEN_0_1']
# Preds:  ['TOKEN_0_4', 'TOKEN_0_4', 'TOKEN_0_4', 'TOKEN_1_8', 'TOKEN_1_1', 'TOKEN_1_1', 'NEWLINE', 'NEWLINE', 'TOKEN_0_7', 'TOKEN_1_1', 'TOKEN_1_8', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_8', 'TOKEN_0_4', 'NEWLINE', 'NEWLINE', 'TOKEN_0_8', 'TOKEN_1_1']
# Example: 8
# Targs:  ['TOKEN_1_7', 'TOKEN_1_8', 'TOKEN_0_5', 'TOKEN_1_4', 'TOKEN_0_1', 'NEWLINE', 'TOKEN_1_6', 'TOKEN_1_2', 'TOKEN_0_1', 'TOKEN_0_1', 'TOKEN_0_2', 'TOKEN_1_5', 'TOKEN_0_7', 'TOKEN_1_5', 'NEWLINE', 'TOKEN_1_7', 'TOKEN_1_2', 'TOKEN_0_5', 'TOKEN_1_8', 'TOKEN_1_6']
# Preds:  ['TOKEN_0_4', 'TOKEN_1_8', 'TOKEN_0_4', 'TOKEN_1_1', 'NEWLINE', 'NEWLINE', 'TOKEN_1_7', 'TOKEN_0_4', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1', 'NEWLINE', 'NEWLINE', 'TOKEN_1_2', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1']
# Example: 9
# Targs:  ['TOKEN_0_2', 'TOKEN_1_8', 'TOKEN_0_7', 'TOKEN_1_3', 'TOKEN_0_8', 'NEWLINE', 'TOKEN_1_6', 'TOKEN_0_1', 'TOKEN_0_1', 'TOKEN_1_4', 'TOKEN_0_7', 'TOKEN_1_2', 'TOKEN_1_5', 'NEWLINE', 'TOKEN_0_5', 'TOKEN_1_1', 'TOKEN_1_7', 'TOKEN_0_7', 'TOKEN_0_7', 'NEWLINE']
# Preds:  ['TOKEN_0_4', 'TOKEN_0_4', 'TOKEN_1_8', 'TOKEN_1_8', 'TOKEN_1_1', 'NEWLINE', 'TOKEN_0_8', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1', 'NEWLINE', 'TOKEN_1_7', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1', 'TOKEN_1_1', 'NEWLINE']
